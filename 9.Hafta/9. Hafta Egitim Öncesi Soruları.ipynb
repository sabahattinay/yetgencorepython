# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# ```
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
class Vehicle:
    def __init__(self, yap, model, yıl):
        self.yap = yap
        self.model = model
        self.yil = yıl

class Bus(Vehicle):
    def oturmaKapasitesi(self, kapasite=50):
        self.kapasite = kapasite
        print(f"Oturma kapasitesi {self.kapasite} yolcudur")

benOto = Bus("Mercedes", "Travego", 2021)
benOto.oturmaKapasitesi()
# Out:
# Oturma kapasitesi 50 yolcudur

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.

# %%
class Vehicle:
    def __init__(self, yap, model, yıl):
        self.yap = yap
        self.model = model
        self.yil = yıl

class Bus(Vehicle):
    def oturmaKapasitesi(self, kapasite=50):
        self.kapasite = kapasite
        print(f"Oturma kapasitesi {self.kapasite} yolcudur")

class School_bus(Bus):
    pass

otoArac = School_bus("Volvo", "B7L", 2020)

print(isinstance(otoArac, Vehicle)) # True
# Out:
# True
